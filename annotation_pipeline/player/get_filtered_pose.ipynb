# %% [markdown]
# # Obtain filtered player id poses from raw poses (no GT) and court corners (singles only)
#
# Raw poses: top-down multi-pose detection results for all people detected, with bbox conf > 0.6, keypoint conf > 0.3
#
# Desired output: Frame, id, x1, y1, x2, y2, 0_x, 0_y... 16_x, 16_y. If pose not visible, fill with zeros. If one player is not visible, fill with 0s for bbox and pose coords
#
# Approach (singles):
#
# 1. Filter out poses with left foot outside of court, with some relaxation boundaries. False positive better than false negative.
# 2. Pick the top 2 remaining with the highest confidence. Nearer to camera is assigned player 1, further assigned player 2.
# 3. If less than 2 boxes left in a frame, use the previous frame. (indefinitely prev)If still not found, then input with zeros.
#
#
# For doubles, we only have the gt pose, since we can't automatically differentiate between players of the same team without GT id labels.

# %%
import cv2
import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from collections import namedtuple

# %%
raw_rootdir = 'raw_pose_bbox/'
crt_rootdir = '../../../datasets/'

# %%
raw_file = 'raw_pose_bbox/pose_bbox_pro/match1/1_01_00_pose_bbox.csv'
crt_file = "../../../datasets/court_corners_pro.csv" 

df_raw = pd.read_csv(raw_file)
df_crt = pd.read_csv(crt_file)

# %%
df_raw.head()
# Out:
#    Frame        x1        y1        x2        y2  bbox_conf       0_x  \
# 0      0  0.471874  0.405537  0.510999  0.583816   0.993157  0.490457
# 1      0  0.557423  0.578038  0.607258  0.854553   0.991925  0.578796
# 2      0  0.342985  0.305662  0.377258  0.403028   0.819770  0.360656
# 3      0  0.131730  0.315437  0.164492  0.406402   0.795672  0.146945
# 4      1  0.471799  0.406428  0.511849  0.585271   0.995671  0.490842
#
#         0_y       1_x       1_y  ...      12_x      12_y      13_x      13_y  \
# 0  0.420974  0.491763  0.416332  ...  0.483928  0.495257  0.495027  0.532398
# 1  0.605582  0.579809  0.601981  ...  0.587910  0.697394  0.574746  0.749600
# 2  0.326771  0.362083  0.322333  ...  0.354238  0.387624  0.365826  0.413931
# 3  0.336342  0.148278  0.333973  ...  0.142615  0.390826  0.153441  0.416588
# 4  0.419585  0.492152  0.416092  ...  0.484292  0.495267  0.494771  0.532526
#
#        14_x      14_y      15_x      15_y      16_x      16_y
# 0  0.483928  0.530077  0.495027  0.569540  0.484581  0.567218
# 1  0.585885  0.753201  0.576771  0.800006  0.580821  0.805407
# 2  0.352990  0.413931  0.368679  0.413931  0.352277  0.413931
# 3  0.142781  0.416588  0.156106  0.416588  0.142781  0.416588
# 4  0.483637  0.530197  0.493462  0.569785  0.484947  0.566292
#
# [5 rows x 40 columns]

# %%
df_crt.head()
# Out:
#    Unnamed: 0                                               path  tl_x  tl_y  \
# 0           0  ../profession_dataset/match1/rally_video/1_02_...   401   380
# 1           1  ../profession_dataset/match1/rally_video/1_02_...   401   380
# 2           2  ../profession_dataset/match1/rally_video/1_06_...   401   380
# 3           3  ../profession_dataset/match1/rally_video/1_02_...   401   380
# 4           4  ../profession_dataset/match1/rally_video/1_03_...   401   380
#
#    tr_x  tr_y  br_x  br_y  bl_x  bl_y  ...  width  height     _tl_x     _tl_y  \
# 0   877   380  1006   668   273   672  ...   1280     720  0.313281  0.527778
# 1   877   380  1006   668   273   672  ...   1280     720  0.313281  0.527778
# 2   877   380  1006   668   273   672  ...   1280     720  0.313281  0.527778
# 3   877   380  1006   668   273   672  ...   1280     720  0.313281  0.527778
# 4   877   380  1006   668   273   672  ...   1280     720  0.313281  0.527778
#
#       _tr_x     _tr_y     _br_x     _br_y     _bl_x     _bl_y
# 0  0.685156  0.527778  0.785937  0.927778  0.213281  0.933333
# 1  0.685156  0.527778  0.785937  0.927778  0.213281  0.933333
# 2  0.685156  0.527778  0.785937  0.927778  0.213281  0.933333
# 3  0.685156  0.527778  0.785937  0.927778  0.213281  0.933333
# 4  0.685156  0.527778  0.785937  0.927778  0.213281  0.933333
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Functions

# %%
def format_crt_pts(df_crt_rel, relax=0.15):
    # format court points
    crt_dict = df_crt_rel.to_dict('records')
    crt_pts = np.zeros((4,2))
    # fill up full court points
    crt_pts[0][0], crt_pts[0][1], crt_pts[1][0], crt_pts[1][1], crt_pts[2][0], crt_pts[2][1], crt_pts[3][0], crt_pts[3][1] = \
        (1-relax)*crt_dict[0]['_tl_x'], (1-relax)*crt_dict[0]['_tl_y'], \
        (1+relax)*crt_dict[0]['_tr_x'], (1-relax)*crt_dict[0]['_tr_y'], \
        (1+relax)*crt_dict[0]['_br_x'], (1+relax)*crt_dict[0]['_br_y'], \
        (1-relax)*crt_dict[0]['_bl_x'], (1+relax)*crt_dict[0]['_bl_y']
    # fill up court points for only the near half
    crt_pts_half_near = crt_pts.copy()
    crt_pts_half_near[0][0], crt_pts_half_near[0][1] = 0.5*(crt_pts[0][0] + crt_pts[3][0]), 0.5*(crt_pts[0][1] + crt_pts[3][1])
    crt_pts_half_near[1][0], crt_pts_half_near[1][1] = 0.5*(crt_pts[1][0] + crt_pts[2][0]), 0.5*(crt_pts[1][1] + crt_pts[2][1])
    # fill up court points for only the far half
    crt_pts_half_far = crt_pts.copy()
    crt_pts_half_far[3][0], crt_pts_half_far[3][1] = crt_pts_half_near[0][0], crt_pts_half_near[0][1]
    crt_pts_half_far[2][0], crt_pts_half_far[2][1] = crt_pts_half_near[1][0], crt_pts_half_near[1][1]

    crt_pts = np.float32(crt_pts.reshape((-1,1,2)))
    crt_pts_half_near = np.float32(crt_pts_half_near.reshape((-1,1,2)))
    crt_pts_half_far = np.float32(crt_pts_half_far.reshape((-1,1,2)))
    
    return crt_pts, crt_pts_half_near, crt_pts_half_far

# %%
def create_dummy_rowdict(fr):
    row = {}
    row['Frame'] = fr
    row['x1'], row['y1'], row['x2'], row['y2'], row['bbox_conf'] = 0, 0, 0, 0, 0
    for p in range(17):
        row[str(p) + '_x'], row[str(p) + '_y'] = 0, 0
        
    return row

# %%
def get_filtered_pose(df_raw, df_crt, crt_orig_path, relax=0.15):
    df_crt_rel = df_crt[df_crt['path'] == crt_orig_path][['_tl_x', '_tl_y', '_tr_x', '_tr_y', '_br_x', '_br_y', '_bl_x', '_bl_y']]
    
    # format court points
    crt_pts, crt_pts_half_near, crt_pts_half_far = format_crt_pts(df_crt_rel, relax=relax)

    total_frame = df_raw['Frame'].to_numpy()[-1] + 1
    outrows_list = []
    for fr in range(total_frame):
        df_raw_tmp = df_raw[df_raw['Frame'] == fr].sort_values(by=['bbox_conf'], ascending=False) # sort by confidence
        listdict_raw = df_raw_tmp.to_dict('records')

        # select rows that lie within court
        selrows_list = []
        for rowi in listdict_raw:
            left_foot_coord = (rowi['16_x'], rowi['16_y'])
            # check if point is in crt. 1- in, 0 -on line, -1 out
            in_crt = cv2.pointPolygonTest(crt_pts, left_foot_coord, False)
            if in_crt != -1:
                selrows_list.append(rowi)

        # identify near and far row
        # CASE 1
        if len(selrows_list) >= 2:
            # check which row is which id based on distance from camera
            if selrows_list[0]['16_y'] > selrows_list[1]['16_y']:
                near_row, far_row = selrows_list[0], selrows_list[1]
            else:
                near_row, far_row = selrows_list[1], selrows_list[0]
        # CASE 2
        elif len(selrows_list) == 1:
            left_foot_coord = (selrows_list[0]['16_x'], selrows_list[0]['16_y'])
            # check if point is in crt. 1- in, 0 -on line, -1 out
            in_near_crt = cv2.pointPolygonTest(crt_pts_half_near, left_foot_coord, False)
            if in_near_crt != -1:
                near_row = selrows_list[0]

                # reuse far row from previous frame, or set to zero if not found
                try:
                    far_row['Frame'] = fr
                except NameError:
                    far_row = create_dummy_rowdict(fr)
            else:
                far_row = selrows_list[0]

                # reuse near row from previous frame, or set to zero if not found
                try:
                    near_row['Frame'] = fr
                except NameError:
                    near_row = create_dummy_rowdict(fr)
        # CASE 3
        else:
            # reuse near and far rows from previous
            try:
                near_row['Frame'] = fr
                far_row['Frame'] = fr
            except NameError:
                far_row = create_dummy_rowdict(fr)
                near_row = create_dummy_rowdict(fr)

        near_row['id'] = 1
        far_row['id'] = 2

        outrows_list.append(near_row.copy())
        outrows_list.append(far_row.copy())

    df_out = pd.DataFrame(outrows_list)
    return df_out

# %%
def save_filtered_pose(raw_rootdir, crtfile, out_rootdir, relax=0.15):
    if 'pro' in raw_rootdir:
        crt_orig_rootpath = '../profession_dataset'
    elif 'am' in raw_rootdir:
        crt_orig_rootpath = '../vids/difficult_dataset'
    df_crt = pd.read_csv(crtfile)
    for matchdir in sorted(os.listdir(raw_rootdir)):
        outdir = os.path.join(out_rootdir, matchdir)
        if not os.path.exists(outdir):
            os.makedirs(outdir)
        for posecsv in sorted(os.listdir(os.path.join(raw_rootdir, matchdir))):
            basename = posecsv.split('_pose_bbox.csv')[0]
            crt_orig_path = os.path.join(crt_orig_rootpath, matchdir, 'rally_video', basename + '.mp4')
            rawcsv = os.path.join(raw_rootdir, matchdir, posecsv)
            outcsv = os.path.join(outdir, basename + '_filtered2pose.csv')
            print(outcsv, ' saved')

            df_raw = pd.read_csv(rawcsv)

            df_out = get_filtered_pose(df_raw, df_crt, crt_orig_path, relax=relax)
            df_out.to_csv(outcsv, index=False)

# %% [markdown]
# ## am-singles

# %%
raw_rootdir_am_singles = os.path.join(raw_rootdir, 'pose_bbox_am_singles')
out_rootdir_am_singles = 'filtered2_pose_bbox/am_singles_filtered2pose/'
crt_rootdir_am = os.path.join(crt_rootdir, 'court_corners_am.csv')

save_filtered_pose(raw_rootdir_am_singles, crt_rootdir_am, out_rootdir_am_singles, relax=0.15)
# Out:
# filtered2_pose_bbox/am_singles_filtered2pose/match24/1_00_01_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match24/1_01_01_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match24/1_01_02_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match24/1_01_03_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match24/1_01_04_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match24/1_02_04_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match24/1_03_04_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match24/1_03_05_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match24/1_04_05_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match24/1_05_05_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match25/1_01_00_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match25/1_02_00_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match25/1_03_00_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match25/1_04_00_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match25/1_05_00_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match25/1_05_01_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match25/1_05_02_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match25/1_05_03_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match25/1_06_03_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match26/1_00_01_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match26/1_00_02_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match26/1_00_03_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match26/1_01_03_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match26/1_02_03_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match26/1_02_04_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match26/1_02_05_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match_china2/singles0_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match_china2/singles1_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match_china2/singles2_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match_china2/singles3_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match_clementi/casualhalfcourt0_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match_clementi/casualhalfcourt1_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match_yewtee/singles0_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match_yewtee/singles1_filtered2pose.csv  saved
# filtered2_pose_bbox/am_singles_filtered2pose/match_yewtee/singles2_filtered2pose.csv  saved

# %% [markdown]
# ## pro

# %%
raw_rootdir_pro = os.path.join(raw_rootdir, 'pose_bbox_pro')
out_rootdir_pro = 'filtered2_pose_bbox/pro_filtered2pose/'
crt_rootdir_pro = os.path.join(crt_rootdir, 'court_corners_pro.csv')

save_filtered_pose(raw_rootdir_pro, crt_rootdir_pro, out_rootdir_pro, relax=0.15)
# Out:
# filtered2_pose_bbox/pro_filtered2pose/match1/1_01_00_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match1/1_02_00_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match1/1_02_01_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match1/1_02_02_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match1/1_02_03_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match1/1_02_04_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match1/1_03_04_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match1/1_03_05_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match1/1_03_06_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match1/1_06_06_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match1/1_06_08_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match1/1_06_09_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match10/1_03_01_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match10/1_03_03_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match10/1_12_16_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match10/2_04_02_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match10/2_14_08_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match11/1_03_01_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match11/1_07_06_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match11/1_13_13_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match11/2_05_00_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match11/2_15_04_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match12/1_01_00_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match12/1_10_12_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match12/2_01_01_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match12/2_05_14_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match12/3_03_03_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match13/1_09_10_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match13/1_17_15_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match13/2_06_05_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match13/2_07_05_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match13/2_09_08_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match13/2_17_11_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match14/1_17_14_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match14/2_13_06_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match14/2_15_10_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match14/2_19_13_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match14/2_21_17_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match15/1_21_12_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match15/2_14_08_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match15/2_16_12_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match15/2_18_14_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match15/2_19_14_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match16/1_13_20_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match16/2_08_08_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match16/3_12_06_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match16/3_14_09_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match16/3_17_16_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match17/1_02_02_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match17/1_15_13_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match17/2_01_01_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match17/2_08_05_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match17/2_15_11_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match17/2_18_11_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match18/1_06_12_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match18/2_02_02_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match18/3_03_05_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match18/3_12_14_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match18/3_16_17_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match18/3_20_19_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match19/1_01_01_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match19/1_01_03_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match19/1_07_08_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match19/2_12_06_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match19/2_14_08_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match2/1_00_02_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match2/1_02_03_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match2/1_04_03_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match2/1_06_08_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match2/1_06_09_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match2/1_08_11_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match2/1_08_12_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match2/1_09_12_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match20/1_09_05_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match20/1_11_10_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match20/2_00_01_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match20/2_05_08_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match20/2_07_08_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match20/2_19_14_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match21/1_02_01_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match21/1_16_17_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match21/1_19_19_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match21/2_02_03_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match21/2_04_04_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match21/2_09_08_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match21/2_12_08_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match22/1_02_01_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match22/1_07_02_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match22/2_17_18_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match22/2_18_18_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match22/3_15_13_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match23/1_06_04_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match23/1_11_08_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match23/1_17_13_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match23/2_02_03_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match23/2_07_03_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match23/2_12_08_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match3/1_01_00_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match3/1_08_10_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match3/1_12_17_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match3/2_04_07_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match3/2_10_12_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match3/2_18_15_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match3/3_11_10_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match4/1_03_02_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match4/1_15_10_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match4/2_02_05_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match4/2_05_07_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match4/2_14_17_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match4/3_02_00_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match4/3_07_05_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match4/3_18_17_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match5/1_01_01_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match5/1_01_02_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match5/1_19_18_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match5/1_21_19_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match5/2_15_13_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match5/2_20_17_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match6/1_02_00_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match6/1_05_03_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match6/1_11_04_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match6/1_15_06_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match6/1_19_12_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match7/1_02_01_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match7/1_12_13_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match7/2_05_03_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match7/2_14_15_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match7/3_08_05_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match8/1_01_00_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match8/1_05_13_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match8/2_03_06_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match8/2_10_12_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match8/3_02_00_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match8/3_15_08_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match8/3_17_12_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match8/3_21_13_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match9/1_01_03_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match9/1_02_03_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match9/1_04_05_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match9/1_05_06_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match9/1_06_06_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match9/1_07_07_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match9/1_07_10_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match9/1_07_11_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/match9/1_07_14_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match1/1_05_02_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match1/1_05_03_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match1/1_06_03_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match1/1_07_03_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match1/1_07_04_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match1/1_07_06_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match1/1_09_06_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match1/1_09_07_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match1/2_02_07_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match1/2_03_08_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match1/2_03_10_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match2/1_03_03_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match2/1_04_04_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match2/1_11_11_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match2/1_13_12_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match2/1_19_15_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match2/2_02_05_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match2/2_08_12_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match3/1_02_00_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match3/1_03_02_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match3/1_05_02_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match3/1_05_03_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match3/1_06_05_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match3/1_06_06_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match3/1_08_08_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match3/1_08_09_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match3/1_09_15_filtered2pose.csv  saved
# filtered2_pose_bbox/pro_filtered2pose/test_match3/1_10_16_filtered2pose.csv  saved
