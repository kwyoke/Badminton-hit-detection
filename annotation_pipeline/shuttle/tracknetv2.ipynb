# %% [markdown]
# # Connect Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/badminton/annotation_pipeline/shuttle
# Out:
# /content/gdrive/MyDrive/badminton/shuttle

# %% [markdown]
# # Install packages
# Instructions from https://nol.cs.nctu.edu.tw:234/open-source/TrackNetv2/tree/master

# %%
# !pip install pyqt5
# !pip install pandas
# !pip install PyMySQL
# !pip install opencv-python
# !pip install imutils
# !pip install Pillow
# !pip install piexif
# !pip install -U scikit-learn
# !pip install keras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyqt5
#   Downloading PyQt5-5.15.7-cp37-abi3-manylinux1_x86_64.whl (8.4 MB)
#      |████████████████████████████████| 8.4 MB 26.1 MB/s
# Collecting PyQt5-sip<13,>=12.11
#   Downloading PyQt5_sip-12.11.0-cp37-cp37m-manylinux1_x86_64.whl (344 kB)
#      |████████████████████████████████| 344 kB 60.7 MB/s
# Collecting PyQt5-Qt5>=5.15.0
#   Downloading PyQt5_Qt5-5.15.2-py3-none-manylinux2014_x86_64.whl (59.9 MB)
#      |████████████████████████████████| 59.9 MB 1.2 MB/s
# Installing collected packages: PyQt5-sip, PyQt5-Qt5, pyqt5
# Successfully installed PyQt5-Qt5-5.15.2 PyQt5-sip-12.11.0 pyqt5-5.15.7
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2022.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting PyMySQL
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 2.6 MB/s
# Installing collected packages: PyMySQL
# Successfully installed PyMySQL-1.0.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.21.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imutils in /usr/local/lib/python3.7/dist-packages (0.5.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (7.1.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting piexif
#   Downloading piexif-1.1.3-py2.py3-none-any.whl (20 kB)
# Installing collected packages: piexif
# Successfully installed piexif-1.1.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.21.6)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.7.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (2.9.0)

# %%
# !git clone https://nol.cs.nctu.edu.tw:234/open-source/TrackNetv2
# %cd TrackNetv2/3_in_3_out/
# Out:
# /content/gdrive/MyDrive/badminton/shuttle/TrackNetv2/3_in_3_out

# %% [markdown]
# ## Function for shuttle prediction tracking

# %%
import sys
import getopt
import numpy as np
import os
from glob import glob
import piexif
import tensorflow
from tensorflow.keras.utils import array_to_img, img_to_array, load_img
from keras.preprocessing.image import ImageDataGenerator
#from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import *
from keras.layers import *
from TrackNet3 import TrackNet3
import keras.backend as K
from keras import optimizers
import tensorflow as tf
import cv2
from os.path import isfile, join
from PIL import Image
import time
BATCH_SIZE=1
HEIGHT=288
WIDTH=512
#HEIGHT=360
#WIDTH=640
sigma=2.5
mag=1

def genHeatMap(w, h, cx, cy, r, mag):
	if cx < 0 or cy < 0:
		return np.zeros((h, w))
	x, y = np.meshgrid(np.linspace(1, w, w), np.linspace(1, h, h))
	heatmap = ((y - (cy + 1))**2) + ((x - (cx + 1))**2)
	heatmap[heatmap <= r**2] = 1
	heatmap[heatmap > r**2] = 0
	return heatmap*mag

#time: in milliseconds
def custom_time(time):
	remain = int(time / 1000)
	ms = (time / 1000) - remain
	s = remain % 60
	s += ms
	remain = int(remain / 60)
	m = remain % 60
	remain = int(remain / 60)
	h = remain
	#Generate custom time string
	cts = ''
	if len(str(h)) >= 2:
		cts += str(h)
	else:
		for i in range(2 - len(str(h))):
			cts += '0'
		cts += str(h)
	
	cts += ':'

	if len(str(m)) >= 2:
		cts += str(m)
	else:
		for i in range(2 - len(str(m))):
			cts += '0'
		cts += str(m)

	cts += ':'

	if len(str(int(s))) == 1:
		cts += '0'
	cts += str(s)

	return cts


#Loss function
def custom_loss(y_true, y_pred):
	loss = (-1)*(K.square(1 - y_pred) * y_true * K.log(K.clip(y_pred, K.epsilon(), 1)) + K.square(y_pred) * (1 - y_true) * K.log(K.clip(1 - y_pred, K.epsilon(), 1)))
	return K.mean(loss)


def predict_shuttle(videoName, load_weights, out_vidname, out_csvname):
  model = load_model(load_weights, custom_objects={'custom_loss':custom_loss})
  #model.summary()
  print('Beginning predicting......')

  start = time.time()

  f = open(out_csvname, 'w')
  f.write('Frame,Visibility,X,Y,Time\n')

  cap = cv2.VideoCapture(videoName)

  success, image1 = cap.read()
  frame_time1 = custom_time(cap.get(cv2.CAP_PROP_POS_MSEC))
  success, image2 = cap.read()
  frame_time2 = custom_time(cap.get(cv2.CAP_PROP_POS_MSEC))
  success, image3 = cap.read()
  frame_time3 = custom_time(cap.get(cv2.CAP_PROP_POS_MSEC))

  ratio = image1.shape[0] / HEIGHT

  size = (int(WIDTH*ratio), int(HEIGHT*ratio))
  fps = 30

  if videoName[-3:] == 'avi':
    fourcc = cv2.VideoWriter_fourcc(*'DIVX')
  elif videoName[-3:] == 'mp4':
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
  else:
    print('usage: video type can only be .avi or .mp4')
    exit(1)

  out = cv2.VideoWriter(out_vidname, fourcc, fps, size)

  count = 0

  while success:
    unit = []
    #Adjust BGR format (cv2) to RGB format (PIL)
    x1 = image1[...,::-1]
    x2 = image2[...,::-1]
    x3 = image3[...,::-1]
    #Convert np arrays to PIL images
    x1 = array_to_img(x1)
    x2 = array_to_img(x2)
    x3 = array_to_img(x3)
    #Resize the images
    x1 = x1.resize(size = (WIDTH, HEIGHT))
    x2 = x2.resize(size = (WIDTH, HEIGHT))
    x3 = x3.resize(size = (WIDTH, HEIGHT))
    #Convert images to np arrays and adjust to channels first
    x1 = np.moveaxis(img_to_array(x1), -1, 0)
    x2 = np.moveaxis(img_to_array(x2), -1, 0)
    x3 = np.moveaxis(img_to_array(x3), -1, 0)
    #Create data
    unit.append(x1[0])
    unit.append(x1[1])
    unit.append(x1[2])
    unit.append(x2[0])
    unit.append(x2[1])
    unit.append(x2[2])
    unit.append(x3[0])
    unit.append(x3[1])
    unit.append(x3[2])
    unit=np.asarray(unit)	
    unit = unit.reshape((1, 9, HEIGHT, WIDTH))
    unit = unit.astype('float32')
    unit /= 255
    y_pred = model.predict(unit, batch_size=BATCH_SIZE)
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype('float32')
    h_pred = y_pred[0]*255
    h_pred = h_pred.astype('uint8')
    for i in range(3):
      if i == 0:
        frame_time = frame_time1
        image = image1
      elif i == 1:
        frame_time = frame_time2
        image = image2
      elif i == 2:
        frame_time = frame_time3	
        image = image3

      if np.amax(h_pred[i]) <= 0:
        f.write(str(count)+',0,0,0,'+frame_time+'\n')
        out.write(image)
      else:	
        #h_pred
        (cnts, _) = cv2.findContours(h_pred[i].copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        rects = [cv2.boundingRect(ctr) for ctr in cnts]
        max_area_idx = 0
        max_area = rects[max_area_idx][2] * rects[max_area_idx][3]
        for i in range(len(rects)):
          area = rects[i][2] * rects[i][3]
          if area > max_area:
            max_area_idx = i
            max_area = area
        target = rects[max_area_idx]
        (cx_pred, cy_pred) = (int(ratio*(target[0] + target[2] / 2)), int(ratio*(target[1] + target[3] / 2)))

        f.write(str(count)+',1,'+str(cx_pred)+','+str(cy_pred)+','+frame_time+'\n')
        image_cp = np.copy(image)
        cv2.circle(image_cp, (cx_pred, cy_pred), 5, (0,0,255), -1)
        out.write(image_cp)
      count += 1
    success, image1 = cap.read()
    frame_time1 = custom_time(cap.get(cv2.CAP_PROP_POS_MSEC))
    success, image2 = cap.read()
    frame_time2 = custom_time(cap.get(cv2.CAP_PROP_POS_MSEC))
    success, image3 = cap.read()
    frame_time3 = custom_time(cap.get(cv2.CAP_PROP_POS_MSEC))

  f.close()
  out.release()
  end = time.time()
  print('Prediction time:', end-start, 'secs')
  print('Done......')

# %% [markdown]
# # Demo track shuttle

# %%
# %cd TrackNetv2/3_in_3_out/
# Out:
# [Errno 2] No such file or directory: 'TrackNetv2/3_in_3_out/'
# /content/gdrive/MyDrive/badminton/shuttle/TrackNetv2/3_in_3_out

# %%
# !python predict3.py --video_name='/content/gdrive/MyDrive/badminton/shuttle/prodoub3.mp4' --load_weights='model906_30'
# Out:
# Traceback (most recent call last):
#   File "predict3.py", line 7, in <module>
#     from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# ImportError: cannot import name 'array_to_img' from 'keras.preprocessing.image' (/usr/local/lib/python3.7/dist-packages/keras/preprocessing/image.py)

# %%
vid = '/content/gdrive/MyDrive/badminton/shuttle/prodoub3.mp4'
vidout = '/content/gdrive/MyDrive/badminton/shuttle/prodoub3_shuttle.mp4'
csvout = '/content/gdrive/MyDrive/badminton/shuttle/prodoub3_shuttle.csv'
predict_shuttle(vid, 'model906_30', vidout, csvout)
# Out:
# Beginning predicting......
# 1/1 [==============================] - 10s 10s/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# Prediction time: 131.27257466316223 secs
# Done......

# %% [markdown]
# ## Run shuttle tracking and save detections in csv, plus output video

# %%
import os 

# get vid paths
vidpaths = []
dataset_rootdir = '/content/gdrive/MyDrive/badminton/difficult_dataset/' #'../profession_dataset/'
match_dirs = [dataset_rootdir + matchdir for matchdir in sorted(os.listdir(dataset_rootdir))]

for matchdir in match_dirs:
  viddir = matchdir + '/rally_video/'
  vid_dirs = [viddir + vid for vid in os.listdir(viddir) if vid.endswith(".mp4")]
  vidpaths.append(sorted(vid_dirs))

for i in range(len(vidpaths)):
  print(vidpaths[i][0])
  for j in range(len(vidpaths[i])):
    vid = vidpaths[i][j]
    out_dir = 'shuttle_difficult/' + vid.split('/')[-3] + '/'
    if not os.path.exists(out_dir):
      os.makedirs(out_dir)
      
    basename = vid.split('/')[-1]

    vidout = out_dir + basename[:-4] + "_shuttle.mp4"
    csvout = out_dir + basename[:-4] + "_shuttle.csv"

    predict_shuttle(vid, 'model906_30', vidout, csvout)
# Out:
# Streaming output truncated to the last 5000 lines.
# __________________________________________________________________________________________________
# Beginning predicting......
# Prediction time: 29.879156589508057 secs
# Done......
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 9, 288, 512  0           []
#                                 )]
#
#  conv2d_1 (Conv2D)              (None, 64, 288, 512  5248        ['input_1[0][0]']
#                                 )
#
#  activation_1 (Activation)      (None, 64, 288, 512  0           ['conv2d_1[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 64, 288, 512  2048       ['activation_1[0][0]']
#  rmalization)                   )
#
#  conv2d_2 (Conv2D)              (None, 64, 288, 512  36928       ['batch_normalization_1[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 64, 288, 512  0           ['conv2d_2[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 64, 288, 512  2048       ['activation_2[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 144, 256  0          ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 144, 25  73856       ['max_pooling2d_1[0][0]']
#                                 6)
#
#  activation_3 (Activation)      (None, 128, 144, 25  0           ['conv2d_3[0][0]']
#                                 6)
#
#  batch_normalization_3 (BatchNo  (None, 128, 144, 25  1024       ['activation_3[0][0]']
#  rmalization)                   6)
#
#  conv2d_4 (Conv2D)              (None, 128, 144, 25  147584      ['batch_normalization_3[0][0]']
#                                 6)
#
#  activation_4 (Activation)      (None, 128, 144, 25  0           ['conv2d_4[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 144, 25  1024       ['activation_4[0][0]']
#  rmalization)                   6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 128, 72, 128  0          ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 256, 72, 128  295168      ['max_pooling2d_2[0][0]']
#                                 )
#
#  activation_5 (Activation)      (None, 256, 72, 128  0           ['conv2d_5[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 256, 72, 128  512        ['activation_5[0][0]']
#  rmalization)                   )
#
#  conv2d_6 (Conv2D)              (None, 256, 72, 128  590080      ['batch_normalization_5[0][0]']
#                                 )
#
#  activation_6 (Activation)      (None, 256, 72, 128  0           ['conv2d_6[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 256, 72, 128  512        ['activation_6[0][0]']
#  rmalization)                   )
#
#  conv2d_7 (Conv2D)              (None, 256, 72, 128  590080      ['batch_normalization_6[0][0]']
#                                 )
#
#  activation_7 (Activation)      (None, 256, 72, 128  0           ['conv2d_7[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 256, 72, 128  512        ['activation_7[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 256, 36, 64)  0          ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 512, 36, 64)  1180160     ['max_pooling2d_3[0][0]']
#
#  activation_8 (Activation)      (None, 512, 36, 64)  0           ['conv2d_8[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 512, 36, 64)  256        ['activation_8[0][0]']
#  rmalization)
#
#  conv2d_9 (Conv2D)              (None, 512, 36, 64)  2359808     ['batch_normalization_8[0][0]']
#
#  activation_9 (Activation)      (None, 512, 36, 64)  0           ['conv2d_9[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 512, 36, 64)  256        ['activation_9[0][0]']
#  rmalization)
#
#  conv2d_10 (Conv2D)             (None, 512, 36, 64)  2359808     ['batch_normalization_9[0][0]']
#
#  activation_10 (Activation)     (None, 512, 36, 64)  0           ['conv2d_10[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 512, 36, 64)  256        ['activation_10[0][0]']
#  ormalization)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 512, 72, 128  0          ['batch_normalization_10[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 768, 72, 128  0           ['up_sampling2d_1[0][0]',
#                                 )                                 'batch_normalization_7[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 256, 72, 128  1769728     ['concatenate_1[0][0]']
#                                 )
#
#  activation_11 (Activation)     (None, 256, 72, 128  0           ['conv2d_11[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 256, 72, 128  512        ['activation_11[0][0]']
#  ormalization)                  )
#
#  conv2d_12 (Conv2D)             (None, 256, 72, 128  590080      ['batch_normalization_11[0][0]']
#                                 )
#
#  activation_12 (Activation)     (None, 256, 72, 128  0           ['conv2d_12[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 256, 72, 128  512        ['activation_12[0][0]']
#  ormalization)                  )
#
#  conv2d_13 (Conv2D)             (None, 256, 72, 128  590080      ['batch_normalization_12[0][0]']
#                                 )
#
#  activation_13 (Activation)     (None, 256, 72, 128  0           ['conv2d_13[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 256, 72, 128  512        ['activation_13[0][0]']
#  ormalization)                  )
#
#  up_sampling2d_2 (UpSampling2D)  (None, 256, 144, 25  0          ['batch_normalization_13[0][0]']
#                                 6)
#
#  concatenate_2 (Concatenate)    (None, 384, 144, 25  0           ['up_sampling2d_2[0][0]',
#                                 6)                                'batch_normalization_4[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 144, 25  442496      ['concatenate_2[0][0]']
#                                 6)
#
#  activation_14 (Activation)     (None, 128, 144, 25  0           ['conv2d_14[0][0]']
#                                 6)
#
#  batch_normalization_14 (BatchN  (None, 128, 144, 25  1024       ['activation_14[0][0]']
#  ormalization)                  6)
#
#  conv2d_15 (Conv2D)             (None, 128, 144, 25  147584      ['batch_normalization_14[0][0]']
#                                 6)
#
#  activation_15 (Activation)     (None, 128, 144, 25  0           ['conv2d_15[0][0]']
#                                 6)
#
#  batch_normalization_15 (BatchN  (None, 128, 144, 25  1024       ['activation_15[0][0]']
#  ormalization)                  6)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 288, 51  0          ['batch_normalization_15[0][0]']
#                                 2)
#
#  concatenate_3 (Concatenate)    (None, 192, 288, 51  0           ['up_sampling2d_3[0][0]',
#                                 2)                                'batch_normalization_2[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 288, 512  110656      ['concatenate_3[0][0]']
#                                 )
#
#  activation_16 (Activation)     (None, 64, 288, 512  0           ['conv2d_16[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 64, 288, 512  2048       ['activation_16[0][0]']
#  ormalization)                  )
#
#  conv2d_17 (Conv2D)             (None, 64, 288, 512  36928       ['batch_normalization_16[0][0]']
#                                 )
#
#  activation_17 (Activation)     (None, 64, 288, 512  0           ['conv2d_17[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 64, 288, 512  2048       ['activation_17[0][0]']
#  ormalization)                  )
#
#  conv2d_18 (Conv2D)             (None, 3, 288, 512)  195         ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 3, 288, 512)  0           ['conv2d_18[0][0]']
#
# ==================================================================================================
# Total params: 11,342,595
# Trainable params: 11,334,531
# Non-trainable params: 8,064
# __________________________________________________________________________________________________
# Beginning predicting......
# Prediction time: 27.363032341003418 secs
# Done......
# /content/gdrive/MyDrive/badminton/difficult_dataset/match_china2/rally_video/singles0.mp4
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 9, 288, 512  0           []
#                                 )]
#
#  conv2d_1 (Conv2D)              (None, 64, 288, 512  5248        ['input_1[0][0]']
#                                 )
#
#  activation_1 (Activation)      (None, 64, 288, 512  0           ['conv2d_1[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 64, 288, 512  2048       ['activation_1[0][0]']
#  rmalization)                   )
#
#  conv2d_2 (Conv2D)              (None, 64, 288, 512  36928       ['batch_normalization_1[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 64, 288, 512  0           ['conv2d_2[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 64, 288, 512  2048       ['activation_2[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 144, 256  0          ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 144, 25  73856       ['max_pooling2d_1[0][0]']
#                                 6)
#
#  activation_3 (Activation)      (None, 128, 144, 25  0           ['conv2d_3[0][0]']
#                                 6)
#
#  batch_normalization_3 (BatchNo  (None, 128, 144, 25  1024       ['activation_3[0][0]']
#  rmalization)                   6)
#
#  conv2d_4 (Conv2D)              (None, 128, 144, 25  147584      ['batch_normalization_3[0][0]']
#                                 6)
#
#  activation_4 (Activation)      (None, 128, 144, 25  0           ['conv2d_4[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 144, 25  1024       ['activation_4[0][0]']
#  rmalization)                   6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 128, 72, 128  0          ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 256, 72, 128  295168      ['max_pooling2d_2[0][0]']
#                                 )
#
#  activation_5 (Activation)      (None, 256, 72, 128  0           ['conv2d_5[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 256, 72, 128  512        ['activation_5[0][0]']
#  rmalization)                   )
#
#  conv2d_6 (Conv2D)              (None, 256, 72, 128  590080      ['batch_normalization_5[0][0]']
#                                 )
#
#  activation_6 (Activation)      (None, 256, 72, 128  0           ['conv2d_6[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 256, 72, 128  512        ['activation_6[0][0]']
#  rmalization)                   )
#
#  conv2d_7 (Conv2D)              (None, 256, 72, 128  590080      ['batch_normalization_6[0][0]']
#                                 )
#
#  activation_7 (Activation)      (None, 256, 72, 128  0           ['conv2d_7[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 256, 72, 128  512        ['activation_7[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 256, 36, 64)  0          ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 512, 36, 64)  1180160     ['max_pooling2d_3[0][0]']
#
#  activation_8 (Activation)      (None, 512, 36, 64)  0           ['conv2d_8[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 512, 36, 64)  256        ['activation_8[0][0]']
#  rmalization)
#
#  conv2d_9 (Conv2D)              (None, 512, 36, 64)  2359808     ['batch_normalization_8[0][0]']
#
#  activation_9 (Activation)      (None, 512, 36, 64)  0           ['conv2d_9[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 512, 36, 64)  256        ['activation_9[0][0]']
#  rmalization)
#
#  conv2d_10 (Conv2D)             (None, 512, 36, 64)  2359808     ['batch_normalization_9[0][0]']
#
#  activation_10 (Activation)     (None, 512, 36, 64)  0           ['conv2d_10[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 512, 36, 64)  256        ['activation_10[0][0]']
#  ormalization)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 512, 72, 128  0          ['batch_normalization_10[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 768, 72, 128  0           ['up_sampling2d_1[0][0]',
#                                 )                                 'batch_normalization_7[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 256, 72, 128  1769728     ['concatenate_1[0][0]']
#                                 )
#
#  activation_11 (Activation)     (None, 256, 72, 128  0           ['conv2d_11[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 256, 72, 128  512        ['activation_11[0][0]']
#  ormalization)                  )
#
#  conv2d_12 (Conv2D)             (None, 256, 72, 128  590080      ['batch_normalization_11[0][0]']
#                                 )
#
#  activation_12 (Activation)     (None, 256, 72, 128  0           ['conv2d_12[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 256, 72, 128  512        ['activation_12[0][0]']
#  ormalization)                  )
#
#  conv2d_13 (Conv2D)             (None, 256, 72, 128  590080      ['batch_normalization_12[0][0]']
#                                 )
#
#  activation_13 (Activation)     (None, 256, 72, 128  0           ['conv2d_13[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 256, 72, 128  512        ['activation_13[0][0]']
#  ormalization)                  )
#
#  up_sampling2d_2 (UpSampling2D)  (None, 256, 144, 25  0          ['batch_normalization_13[0][0]']
#                                 6)
#
#  concatenate_2 (Concatenate)    (None, 384, 144, 25  0           ['up_sampling2d_2[0][0]',
#                                 6)                                'batch_normalization_4[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 144, 25  442496      ['concatenate_2[0][0]']
#                                 6)
#
#  activation_14 (Activation)     (None, 128, 144, 25  0           ['conv2d_14[0][0]']
#                                 6)
#
#  batch_normalization_14 (BatchN  (None, 128, 144, 25  1024       ['activation_14[0][0]']
#  ormalization)                  6)
#
#  conv2d_15 (Conv2D)             (None, 128, 144, 25  147584      ['batch_normalization_14[0][0]']
#                                 6)
#
#  activation_15 (Activation)     (None, 128, 144, 25  0           ['conv2d_15[0][0]']
#                                 6)
#
#  batch_normalization_15 (BatchN  (None, 128, 144, 25  1024       ['activation_15[0][0]']
#  ormalization)                  6)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 288, 51  0          ['batch_normalization_15[0][0]']
#                                 2)
#
#  concatenate_3 (Concatenate)    (None, 192, 288, 51  0           ['up_sampling2d_3[0][0]',
#                                 2)                                'batch_normalization_2[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 288, 512  110656      ['concatenate_3[0][0]']
#                                 )
#
#  activation_16 (Activation)     (None, 64, 288, 512  0           ['conv2d_16[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 64, 288, 512  2048       ['activation_16[0][0]']
#  ormalization)                  )
#
#  conv2d_17 (Conv2D)             (None, 64, 288, 512  36928       ['batch_normalization_16[0][0]']
#                                 )
#
#  activation_17 (Activation)     (None, 64, 288, 512  0           ['conv2d_17[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 64, 288, 512  2048       ['activation_17[0][0]']
#  ormalization)                  )
#
#  conv2d_18 (Conv2D)             (None, 3, 288, 512)  195         ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 3, 288, 512)  0           ['conv2d_18[0][0]']
#
# ==================================================================================================
# Total params: 11,342,595
# Trainable params: 11,334,531
# Non-trainable params: 8,064
# __________________________________________________________________________________________________
# Beginning predicting......
# Prediction time: 23.867570638656616 secs
# Done......
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 9, 288, 512  0           []
#                                 )]
#
#  conv2d_1 (Conv2D)              (None, 64, 288, 512  5248        ['input_1[0][0]']
#                                 )
#
#  activation_1 (Activation)      (None, 64, 288, 512  0           ['conv2d_1[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 64, 288, 512  2048       ['activation_1[0][0]']
#  rmalization)                   )
#
#  conv2d_2 (Conv2D)              (None, 64, 288, 512  36928       ['batch_normalization_1[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 64, 288, 512  0           ['conv2d_2[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 64, 288, 512  2048       ['activation_2[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 144, 256  0          ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 144, 25  73856       ['max_pooling2d_1[0][0]']
#                                 6)
#
#  activation_3 (Activation)      (None, 128, 144, 25  0           ['conv2d_3[0][0]']
#                                 6)
#
#  batch_normalization_3 (BatchNo  (None, 128, 144, 25  1024       ['activation_3[0][0]']
#  rmalization)                   6)
#
#  conv2d_4 (Conv2D)              (None, 128, 144, 25  147584      ['batch_normalization_3[0][0]']
#                                 6)
#
#  activation_4 (Activation)      (None, 128, 144, 25  0           ['conv2d_4[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 144, 25  1024       ['activation_4[0][0]']
#  rmalization)                   6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 128, 72, 128  0          ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 256, 72, 128  295168      ['max_pooling2d_2[0][0]']
#                                 )
#
#  activation_5 (Activation)      (None, 256, 72, 128  0           ['conv2d_5[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 256, 72, 128  512        ['activation_5[0][0]']
#  rmalization)                   )
#
#  conv2d_6 (Conv2D)              (None, 256, 72, 128  590080      ['batch_normalization_5[0][0]']
#                                 )
#
#  activation_6 (Activation)      (None, 256, 72, 128  0           ['conv2d_6[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 256, 72, 128  512        ['activation_6[0][0]']
#  rmalization)                   )
#
#  conv2d_7 (Conv2D)              (None, 256, 72, 128  590080      ['batch_normalization_6[0][0]']
#                                 )
#
#  activation_7 (Activation)      (None, 256, 72, 128  0           ['conv2d_7[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 256, 72, 128  512        ['activation_7[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 256, 36, 64)  0          ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 512, 36, 64)  1180160     ['max_pooling2d_3[0][0]']
#
#  activation_8 (Activation)      (None, 512, 36, 64)  0           ['conv2d_8[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 512, 36, 64)  256        ['activation_8[0][0]']
#  rmalization)
#
#  conv2d_9 (Conv2D)              (None, 512, 36, 64)  2359808     ['batch_normalization_8[0][0]']
#
#  activation_9 (Activation)      (None, 512, 36, 64)  0           ['conv2d_9[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 512, 36, 64)  256        ['activation_9[0][0]']
#  rmalization)
#
#  conv2d_10 (Conv2D)             (None, 512, 36, 64)  2359808     ['batch_normalization_9[0][0]']
#
#  activation_10 (Activation)     (None, 512, 36, 64)  0           ['conv2d_10[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 512, 36, 64)  256        ['activation_10[0][0]']
#  ormalization)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 512, 72, 128  0          ['batch_normalization_10[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 768, 72, 128  0           ['up_sampling2d_1[0][0]',
#                                 )                                 'batch_normalization_7[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 256, 72, 128  1769728     ['concatenate_1[0][0]']
#                                 )
#
# ...
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 144, 25  73856       ['max_pooling2d_1[0][0]']
#                                 6)
#
#  activation_3 (Activation)      (None, 128, 144, 25  0           ['conv2d_3[0][0]']
#                                 6)
#
#  batch_normalization_3 (BatchNo  (None, 128, 144, 25  1024       ['activation_3[0][0]']
#  rmalization)                   6)
#
#  conv2d_4 (Conv2D)              (None, 128, 144, 25  147584      ['batch_normalization_3[0][0]']
#                                 6)
#
#  activation_4 (Activation)      (None, 128, 144, 25  0           ['conv2d_4[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 144, 25  1024       ['activation_4[0][0]']
#  rmalization)                   6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 128, 72, 128  0          ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 256, 72, 128  295168      ['max_pooling2d_2[0][0]']
#                                 )
#
#  activation_5 (Activation)      (None, 256, 72, 128  0           ['conv2d_5[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 256, 72, 128  512        ['activation_5[0][0]']
#  rmalization)                   )
#
#  conv2d_6 (Conv2D)              (None, 256, 72, 128  590080      ['batch_normalization_5[0][0]']
#                                 )
#
#  activation_6 (Activation)      (None, 256, 72, 128  0           ['conv2d_6[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 256, 72, 128  512        ['activation_6[0][0]']
#  rmalization)                   )
#
#  conv2d_7 (Conv2D)              (None, 256, 72, 128  590080      ['batch_normalization_6[0][0]']
#                                 )
#
#  activation_7 (Activation)      (None, 256, 72, 128  0           ['conv2d_7[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 256, 72, 128  512        ['activation_7[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 256, 36, 64)  0          ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 512, 36, 64)  1180160     ['max_pooling2d_3[0][0]']
#
#  activation_8 (Activation)      (None, 512, 36, 64)  0           ['conv2d_8[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 512, 36, 64)  256        ['activation_8[0][0]']
#  rmalization)
#
#  conv2d_9 (Conv2D)              (None, 512, 36, 64)  2359808     ['batch_normalization_8[0][0]']
#
#  activation_9 (Activation)      (None, 512, 36, 64)  0           ['conv2d_9[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 512, 36, 64)  256        ['activation_9[0][0]']
#  rmalization)
#
#  conv2d_10 (Conv2D)             (None, 512, 36, 64)  2359808     ['batch_normalization_9[0][0]']
#
#  activation_10 (Activation)     (None, 512, 36, 64)  0           ['conv2d_10[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 512, 36, 64)  256        ['activation_10[0][0]']
#  ormalization)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 512, 72, 128  0          ['batch_normalization_10[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 768, 72, 128  0           ['up_sampling2d_1[0][0]',
#                                 )                                 'batch_normalization_7[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 256, 72, 128  1769728     ['concatenate_1[0][0]']
#                                 )
#
#  activation_11 (Activation)     (None, 256, 72, 128  0           ['conv2d_11[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 256, 72, 128  512        ['activation_11[0][0]']
#  ormalization)                  )
#
#  conv2d_12 (Conv2D)             (None, 256, 72, 128  590080      ['batch_normalization_11[0][0]']
#                                 )
#
#  activation_12 (Activation)     (None, 256, 72, 128  0           ['conv2d_12[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 256, 72, 128  512        ['activation_12[0][0]']
#  ormalization)                  )
#
#  conv2d_13 (Conv2D)             (None, 256, 72, 128  590080      ['batch_normalization_12[0][0]']
#                                 )
#
#  activation_13 (Activation)     (None, 256, 72, 128  0           ['conv2d_13[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 256, 72, 128  512        ['activation_13[0][0]']
#  ormalization)                  )
#
#  up_sampling2d_2 (UpSampling2D)  (None, 256, 144, 25  0          ['batch_normalization_13[0][0]']
#                                 6)
#
#  concatenate_2 (Concatenate)    (None, 384, 144, 25  0           ['up_sampling2d_2[0][0]',
#                                 6)                                'batch_normalization_4[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 144, 25  442496      ['concatenate_2[0][0]']
#                                 6)
#
#  activation_14 (Activation)     (None, 128, 144, 25  0           ['conv2d_14[0][0]']
#                                 6)
#
#  batch_normalization_14 (BatchN  (None, 128, 144, 25  1024       ['activation_14[0][0]']
#  ormalization)                  6)
#
#  conv2d_15 (Conv2D)             (None, 128, 144, 25  147584      ['batch_normalization_14[0][0]']
#                                 6)
#
#  activation_15 (Activation)     (None, 128, 144, 25  0           ['conv2d_15[0][0]']
#                                 6)
#
#  batch_normalization_15 (BatchN  (None, 128, 144, 25  1024       ['activation_15[0][0]']
#  ormalization)                  6)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 288, 51  0          ['batch_normalization_15[0][0]']
#                                 2)
#
#  concatenate_3 (Concatenate)    (None, 192, 288, 51  0           ['up_sampling2d_3[0][0]',
#                                 2)                                'batch_normalization_2[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 288, 512  110656      ['concatenate_3[0][0]']
#                                 )
#
#  activation_16 (Activation)     (None, 64, 288, 512  0           ['conv2d_16[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 64, 288, 512  2048       ['activation_16[0][0]']
#  ormalization)                  )
#
#  conv2d_17 (Conv2D)             (None, 64, 288, 512  36928       ['batch_normalization_16[0][0]']
#                                 )
#
#  activation_17 (Activation)     (None, 64, 288, 512  0           ['conv2d_17[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 64, 288, 512  2048       ['activation_17[0][0]']
#  ormalization)                  )
#
#  conv2d_18 (Conv2D)             (None, 3, 288, 512)  195         ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 3, 288, 512)  0           ['conv2d_18[0][0]']
#
# ==================================================================================================
# Total params: 11,342,595
# Trainable params: 11,334,531
# Non-trainable params: 8,064
# __________________________________________________________________________________________________
# Beginning predicting......
# Prediction time: 45.18105363845825 secs
# Done......
